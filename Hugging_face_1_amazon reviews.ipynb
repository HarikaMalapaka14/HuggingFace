# %% [markdown]
# <a href="https://colab.research.google.com/github/HarikaMalapaka14/HuggingFace/blob/main/Hugging_face_1_amazon%20reviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install transformers[sentencepiece]

# %%
from transformers import pipeline
import pandas as pd

# %%
data_file=pd.read_csv('/content/amazon _reviews.csv')
data_file
# Out:
#                                               reviews
# 0   When you shove the grocery bags in crumpled it...
# 1              The right size. Easy to use. Thank you
# 2            Works well with stainless steel kitchens
# 3                                    It. Holds. Bags.
# 4   The item is small but it is useful. I thought ...
# 5                                      excellent item
# 6   Very easy to install, fits about 10 plastic ba...
# 7                              Absolutely love this!!
# 8   + It looks good despite the over the top shine...
# 9   Not totally in love with this product. I used ...
# 10  I left the last ones at the home i sold.  They...
# 11                                  Gets the job done
# 12  There's little to like or dislike on a grocery...

# %%
data_file['reviews'].tolist()
# Out:
# ["When you shove the grocery bags in crumpled it hold between 18-25. If you roll the bags and fold them into little rectangles it holds up to 35.Fair warning, if you do fold them for it to hold more, they do fall out, dispenses more than one when you pull at them. But this Makes bags easily accessible. I installed mine near bathroom trashcans to make it easy to reset the cans. It's stylish enough to make it inconspicuous and useful.",
#  'The right size. Easy to use. Thank you',
#  'Works well with stainless steel kitchens',
#  'It. Holds. Bags.',
#  'The item is small but it is useful. I thought it would be larger but it is working fine so far.',
#  'excellent item',
#  'Very easy to install, fits about 10 plastic bags. I love the road pink color. Great for organizing extra bags. A great buy!',
#  'Absolutely love this!!',
# ...

# %%
cls=pipeline('sentiment-analysis',model = "finiteautomata/bertweet-base-sentiment-analysis")
res=cls(data_file['reviews'].tolist())
for i in range(0,len(res)):
  print('\n',data_file['reviews'].tolist()[i], res[i])
# Out:
# ...
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0
#  When you shove the grocery bags in crumpled it hold between 18-25. If you roll the bags and fold them into little rectangles it holds up to 35.Fair warning, if you do fold them for it to hold more, they do fall out, dispenses more than one when you pull at them. But this Makes bags easily accessible. I installed mine near bathroom trashcans to make it easy to reset the cans. It's stylish enough to make it inconspicuous and useful. {'label': 'POS', 'score': 0.7105634212493896}
#
#  The right size. Easy to use. Thank you {'label': 'POS', 'score': 0.9777231812477112}
#
#  Works well with stainless steel kitchens {'label': 'POS', 'score': 0.9149402976036072}
#
#  It. Holds. Bags. {'label': 'NEU', 'score': 0.9410389065742493}
#
#  The item is small but it is useful. I thought it would be larger but it is working fine so far. {'label': 'POS', 'score': 0.9802968502044678}
# ...

# %%
cls=pipeline('sentiment-analysis')
res=cls('I"ve been waiting for a HUggingFace course my whole life')
print(res)
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# Xformers is not installed correctly. If you want to use memorry_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# [{'label': 'POSITIVE', 'score': 0.9398069977760315}]

# %%
res=cls('Patient  Amanda suffering from cancer since 10 uyears')
print(res)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9543434381484985}]

# %%
res=cls('Rakesh had gone to movie')
print(res)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9547484517097473}]

# %%
generator = pipeline('text-generation',model='distilgpt2')

res=generator('In this course, we will teach you how to', max_length=30,num_return_sequences=2)

res
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'In this course, we will teach you how to manage resources efficiently, and share a variety of resources. This course will also teach you how to manage'},
#  {'generated_text': 'In this course, we will teach you how to build your brain\n\n\n\n\nThe biggest part: when you do this'}]

# %%
classifier=pipeline('zero-shot-classification')
res=classifier('This is a course about python list comprehension', candidate_labels=['education','politics','Stock market','Business'])
res
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# {'sequence': 'This is a course about python list comprehension',
#  'labels': ['education', 'Business', 'Stock market', 'politics'],
#  'scores': [0.9340483546257019,
#   0.03216400742530823,
#   0.020272348076105118,
#   0.01351520512253046]}

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
model_name='distilbert-base-uncased-finetuned-sst-2-english'
model=AutoModelForSequenceClassification.from_pretrained(model_name)
tokenizer=AutoTokenizer.from_pretrained(model_name)
classifier = pipeline('sentiment-analysis', model=model,tokenizer=tokenizer)
res=classifier('I"ve been waiting for a HUggingFace course my whole life')
print(res)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9398069977760315}]

# %%
sequence='Using a transformer network is simple'
res=tokenizer(sequence)
print(res)
tokens=tokenizer.tokenize(sequence)
print(tokens)
ids=tokenizer.convert_tokens_to_ids(tokens)
print(ids)
decoded_string=tokenizer.decode(ids)
print(decoded_string)
# Out:
# {'input_ids': [101, 2478, 1037, 10938, 2121, 2897, 2003, 3722, 102], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1, 1]}
# ['using', 'a', 'transform', '##er', 'network', 'is', 'simple']
# [2478, 1037, 10938, 2121, 2897, 2003, 3722]
# using a transformer network is simple
